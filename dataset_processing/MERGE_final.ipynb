# %% [markdown]
# ## extracting our required entities from raw data

# %%
import pandas as pd
import os

# List of values to keep
values_to_keep = [
    "employerName", "employerAddressStreet_name", "employerAddressCity",
    "employerAddressState", "employerAddressZip", "einEmployerIdentificationNumber",
    "employeeName", "ssnOfEmployee", "box1WagesTipsAndOtherCompensations",
    "box2FederalIncomeTaxWithheld", "box3SocialSecurityWages",
    "box4SocialSecurityTaxWithheld", "box16StateWagesTips",
    "box17StateIncomeTax", "taxYear"
]

# Folder paths
folder_path = r'C:\Users\HP\Downloads\proj\boxes_transcripts_labels'  # Input TSV folder
output_folder_path = r'C:\Users\HP\Downloads\proj\individual'  # Output Excel folder

# Create output folder if it doesn't exist
os.makedirs(output_folder_path, exist_ok=True)

# Loop through each file in the specified folder
for file in os.listdir(folder_path):
    if file.endswith('.tsv'):
        print(f"Processing file: {file}")  # Debugging statement
        
        # Combine the folder path and file name
        filePath = os.path.join(folder_path, file)
        
        # Read the file, treating it as a CSV (comma-separated file)
        df = pd.read_csv(filePath, sep=',', header=None)

        # Check if the file has the expected 8 columns
        expected_columns = ['start_index', 'end_index', 'x_top_left', 'y_top_left', 
                            'x_bottom_right', 'y_bottom_right', 'transcript', 'field']
        
        if df.shape[1] != len(expected_columns):
            print(f"Skipping {file} due to unexpected column count: {df.shape[1]}")
            continue
        
        # Assign column names
        df.columns = expected_columns

        # Verify required columns exist before proceeding
        if 'field' not in df.columns or 'transcript' not in df.columns:
            print(f"Skipping {file} due to missing required columns.")
            continue

        # Filter the DataFrame to keep only rows where 'field' is in values_to_keep
        df_filtered = df[df["field"].isin(values_to_keep)]

        # Initialize a list to store grouped DataFrames
        grouped_data_frames = []

        # Group by 'field' and concatenate 'transcript'
        for field in values_to_keep:
            if field in df_filtered['field'].values:  # Check if field exists in the filtered DataFrame
                newDataFrame = df_filtered[df_filtered['field'] == field].groupby('field').agg({
                    'transcript': lambda x: ' '.join(x).strip()  # Concatenate and strip whitespace
                }).reset_index()
                
                # Remove spaces within the concatenated text
                newDataFrame['transcript'] = newDataFrame['transcript'].apply(lambda x: x.replace(' ', '').strip())
                
                # Append the grouped DataFrame to the list
                grouped_data_frames.append(newDataFrame)

        # Create a new DataFrame if there are any grouped data
        if grouped_data_frames:
            df_combined = pd.concat(grouped_data_frames, ignore_index=True)

            # Create a new Excel file in the specified output folder
            excel_file_path = os.path.join(output_folder_path, f"{os.path.splitext(file)[0]}.xlsx")

            # Write the combined DataFrame to a new Excel file
            df_combined.to_excel(excel_file_path, index=False)
            print(f"Excel file created: {excel_file_path}")
        else:
            print(f"No relevant data to save for {file}.")

print("Processing complete.")

# -----------------------------------------------
# PART 2: Combine extracted Excel files into one
# -----------------------------------------------

# Define the list of columns to extract
columns = [
    "employerName", "employerAddressStreet_name", "employerAddressCity", 
    "employerAddressState", "employerAddressZip", "einEmployerIdentificationNumber", 
    "employeeName", "ssnOfEmployee", "box1WagesTipsAndOtherCompensations", 
    "box2FederalIncomeTaxWithheld", "box3SocialSecurityWages", 
    "box4SocialSecurityTaxWithheld", "box16StateWagesTips", 
    "box17StateIncomeTax", "taxYear"
]

# Initialize an empty DataFrame to store results
result_df = pd.DataFrame(columns=columns)

# Path where your Excel files are located
path = output_folder_path

# Loop through all Excel files in the specified directory
for filename in os.listdir(path):
    if filename.endswith('.xlsx'):
        # Read the Excel file
        file_path = os.path.join(path, filename)
        df = pd.read_excel(file_path)

        # Check if 'field' and 'transcript' columns exist
        if 'field' not in df.columns or 'transcript' not in df.columns:
            print(f"Skipping {filename} due to missing columns.")
            continue

        # Initialize a new row for the new employee (for each file)
        new_row = {col: None for col in columns}  # Initialize with None for all columns
        
        # Iterate row-wise in the current file
        for _, row in df.iterrows():
            currField = row['field']
            currTranscript = row['transcript']
            
            # Ensure transcript is a string and clean it
            if isinstance(currTranscript, str):
                currTranscript = currTranscript.strip()

            # Set the corresponding field value for the current file's row
            if currField in columns:
                new_row[currField] = currTranscript
        
        # Convert the new_row dictionary into a DataFrame
        new_row_df = pd.DataFrame([new_row])

        # Concatenate the new_row_df with result_df
        result_df = pd.concat([result_df, new_row_df], ignore_index=True)
        
# Convert numeric columns to float (if needed)
numeric_columns = [
    "box1WagesTipsAndOtherCompensations", "box2FederalIncomeTaxWithheld", 
    "box3SocialSecurityWages", "box4SocialSecurityTaxWithheld", 
    "box16StateWagesTips", "box17StateIncomeTax"
]

# Clean the numeric data before converting
for col in numeric_columns:
    result_df[col] = result_df[col].replace({'\$': '', ',': '', ' ': ''}, regex=True)  # Strip spaces, commas, and dollar signs
    result_df[col] = pd.to_numeric(result_df[col], errors='coerce')  # Convert to numeric

# Save the resulting DataFrame to an Excel file
output_file_path = os.path.join(path, 'result.xlsx')
result_df.to_excel(output_file_path, index=False)

print(f"Processing complete. File saved to {output_file_path}.")
# Out:
# Processing file: number1.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number1.xlsx
# Processing file: number10.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number10.xlsx
# Processing file: number100.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number100.xlsx
# Processing file: number101.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number101.xlsx
# Processing file: number102.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number102.xlsx
# Processing file: number103.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number103.xlsx
# Processing file: number104.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number104.xlsx
# Processing file: number105.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number105.xlsx
# Processing file: number106.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number106.xlsx
# Processing file: number107.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number107.xlsx
# Processing file: number108.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number108.xlsx
# Processing file: number109.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number109.xlsx
# Processing file: number11.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number11.xlsx
# Processing file: number110.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number110.xlsx
# Processing file: number111.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number111.xlsx
# Processing file: number112.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number112.xlsx
# Processing file: number113.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number113.xlsx
# Processing file: number114.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number114.xlsx
# Processing file: number115.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number115.xlsx
# Processing file: number116.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number116.xlsx
# Processing file: number117.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number117.xlsx
# Processing file: number118.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number118.xlsx
# Processing file: number119.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number119.xlsx
# Processing file: number12.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number12.xlsx
# Processing file: number120.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number120.xlsx
# Processing file: number121.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number121.xlsx
# Processing file: number122.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number122.xlsx
# Processing file: number123.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number123.xlsx
# Processing file: number124.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number124.xlsx
# Processing file: number125.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number125.xlsx
# Processing file: number126.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number126.xlsx
# Processing file: number127.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number127.xlsx
# Processing file: number128.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number128.xlsx
# Processing file: number129.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number129.xlsx
# Processing file: number13.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number13.xlsx
# Processing file: number130.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number130.xlsx
# Processing file: number131.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number131.xlsx
# Processing file: number132.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number132.xlsx
# Processing file: number133.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number133.xlsx
# Processing file: number134.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number134.xlsx
# Processing file: number135.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number135.xlsx
# Processing file: number136.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number136.xlsx
# Processing file: number137.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number137.xlsx
# Processing file: number138.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number138.xlsx
# Processing file: number139.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number139.xlsx
# Processing file: number14.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number14.xlsx
# Processing file: number140.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number140.xlsx
# Processing file: number141.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number141.xlsx
# Processing file: number142.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number142.xlsx
# Processing file: number143.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number143.xlsx
# Processing file: number144.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number144.xlsx
# Processing file: number145.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number145.xlsx
# Processing file: number146.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number146.xlsx
# Processing file: number147.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number147.xlsx
# Processing file: number148.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number148.xlsx
# Processing file: number149.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number149.xlsx
# Processing file: number15.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number15.xlsx
# Processing file: number150.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number150.xlsx
# Processing file: number151.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number151.xlsx
# Processing file: number152.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number152.xlsx
# Processing file: number153.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number153.xlsx
# Processing file: number154.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number154.xlsx
# Processing file: number155.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number155.xlsx
# Processing file: number156.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number156.xlsx
# Processing file: number157.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number157.xlsx
# Processing file: number158.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number158.xlsx
# Processing file: number159.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number159.xlsx
# Processing file: number16.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number16.xlsx
# Processing file: number160.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number160.xlsx
# Processing file: number161.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number161.xlsx
# Processing file: number162.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number162.xlsx
# Processing file: number163.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number163.xlsx
# Processing file: number164.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number164.xlsx
# Processing file: number165.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number165.xlsx
# Processing file: number166.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number166.xlsx
# Processing file: number167.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number167.xlsx
# Processing file: number168.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number168.xlsx
# Processing file: number169.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number169.xlsx
# Processing file: number17.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number17.xlsx
# Processing file: number170.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number170.xlsx
# Processing file: number171.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number171.xlsx
# Processing file: number172.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number172.xlsx
# Processing file: number173.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number173.xlsx
# Processing file: number174.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number174.xlsx
# Processing file: number175.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number175.xlsx
# Processing file: number176.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number176.xlsx
# Processing file: number177.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number177.xlsx
# Processing file: number178.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number178.xlsx
# Processing file: number179.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number179.xlsx
# Processing file: number18.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number18.xlsx
# Processing file: number180.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number180.xlsx
# Processing file: number181.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number181.xlsx
# Processing file: number182.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number182.xlsx
# Processing file: number183.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number183.xlsx
# Processing file: number184.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number184.xlsx
# Processing file: number185.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number185.xlsx
# Processing file: number186.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number186.xlsx
# Processing file: number187.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number187.xlsx
# Processing file: number188.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number188.xlsx
# Processing file: number189.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number189.xlsx
# Processing file: number19.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number19.xlsx
# Processing file: number190.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number190.xlsx
# Processing file: number191.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number191.xlsx
# Processing file: number192.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number192.xlsx
# Processing file: number193.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number193.xlsx
# Processing file: number194.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number194.xlsx
# Processing file: number195.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number195.xlsx
# Processing file: number196.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number196.xlsx
# Processing file: number197.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number197.xlsx
# Processing file: number198.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number198.xlsx
# Processing file: number199.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number199.xlsx
# Processing file: number2.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number2.xlsx
# Processing file: number20.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number20.xlsx
# Processing file: number200.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number200.xlsx
# Processing file: number201.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number201.xlsx
# Processing file: number202.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number202.xlsx
# Processing file: number203.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number203.xlsx
# Processing file: number204.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number204.xlsx
# Processing file: number205.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number205.xlsx
# Processing file: number206.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number206.xlsx
# Processing file: number207.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number207.xlsx
# Processing file: number208.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number208.xlsx
# Processing file: number209.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number209.xlsx
# Processing file: number21.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number21.xlsx
# Processing file: number210.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number210.xlsx
# Processing file: number211.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number211.xlsx
# Processing file: number212.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number212.xlsx
# Processing file: number213.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number213.xlsx
# Processing file: number214.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number214.xlsx
# Processing file: number215.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number215.xlsx
# Processing file: number216.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number216.xlsx
# Processing file: number217.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number217.xlsx
# Processing file: number218.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number218.xlsx
# Processing file: number219.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number219.xlsx
# Processing file: number22.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number22.xlsx
# Processing file: number220.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number220.xlsx
# Processing file: number221.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number221.xlsx
# Processing file: number222.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number222.xlsx
# Processing file: number223.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number223.xlsx
# Processing file: number224.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number224.xlsx
# Processing file: number225.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number225.xlsx
# Processing file: number226.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number226.xlsx
# Processing file: number227.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number227.xlsx
# Processing file: number228.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number228.xlsx
# Processing file: number229.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number229.xlsx
# Processing file: number23.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number23.xlsx
# Processing file: number230.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number230.xlsx
# Processing file: number231.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number231.xlsx
# Processing file: number232.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number232.xlsx
# Processing file: number233.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number233.xlsx
# Processing file: number234.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number234.xlsx
# Processing file: number235.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number235.xlsx
# Processing file: number236.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number236.xlsx
# Processing file: number237.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number237.xlsx
# Processing file: number238.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number238.xlsx
# Processing file: number239.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number239.xlsx
# Processing file: number24.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number24.xlsx
# Processing file: number240.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number240.xlsx
# Processing file: number241.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number241.xlsx
# Processing file: number242.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number242.xlsx
# Processing file: number243.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number243.xlsx
# Processing file: number244.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number244.xlsx
# Processing file: number245.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number245.xlsx
# Processing file: number246.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number246.xlsx
# Processing file: number247.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number247.xlsx
# Processing file: number248.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number248.xlsx
# Processing file: number249.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number249.xlsx
# Processing file: number25.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number25.xlsx
# Processing file: number250.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number250.xlsx
# Processing file: number251.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number251.xlsx
# Processing file: number252.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number252.xlsx
# Processing file: number253.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number253.xlsx
# Processing file: number254.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number254.xlsx
# Processing file: number255.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number255.xlsx
# Processing file: number256.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number256.xlsx
# Processing file: number257.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number257.xlsx
# Processing file: number258.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number258.xlsx
# Processing file: number259.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number259.xlsx
# Processing file: number26.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number26.xlsx
# Processing file: number260.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number260.xlsx
# Processing file: number261.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number261.xlsx
# Processing file: number262.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number262.xlsx
# Processing file: number263.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number263.xlsx
# Processing file: number264.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number264.xlsx
# Processing file: number265.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number265.xlsx
# Processing file: number266.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number266.xlsx
# Processing file: number267.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number267.xlsx
# Processing file: number268.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number268.xlsx
# Processing file: number269.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number269.xlsx
# Processing file: number27.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number27.xlsx
# Processing file: number270.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number270.xlsx
# Processing file: number271.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number271.xlsx
# Processing file: number272.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number272.xlsx
# Processing file: number273.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number273.xlsx
# Processing file: number274.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number274.xlsx
# Processing file: number275.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number275.xlsx
# Processing file: number276.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number276.xlsx
# Processing file: number277.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number277.xlsx
# Processing file: number278.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number278.xlsx
# Processing file: number279.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number279.xlsx
# Processing file: number28.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number28.xlsx
# Processing file: number280.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number280.xlsx
# Processing file: number281.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number281.xlsx
# Processing file: number282.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number282.xlsx
# Processing file: number283.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number283.xlsx
# Processing file: number284.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number284.xlsx
# Processing file: number285.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number285.xlsx
# Processing file: number286.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number286.xlsx
# Processing file: number287.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number287.xlsx
# Processing file: number288.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number288.xlsx
# Processing file: number289.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number289.xlsx
# Processing file: number29.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number29.xlsx
# Processing file: number290.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number290.xlsx
# Processing file: number291.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number291.xlsx
# Processing file: number292.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number292.xlsx
# Processing file: number293.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number293.xlsx
# Processing file: number294.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number294.xlsx
# Processing file: number295.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number295.xlsx
# Processing file: number296.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number296.xlsx
# Processing file: number297.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number297.xlsx
# Processing file: number298.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number298.xlsx
# Processing file: number299.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number299.xlsx
# Processing file: number3.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number3.xlsx
# Processing file: number30.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number30.xlsx
# Processing file: number300.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number300.xlsx
# Processing file: number301.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number301.xlsx
# Processing file: number302.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number302.xlsx
# Processing file: number303.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number303.xlsx
# Processing file: number304.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number304.xlsx
# Processing file: number305.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number305.xlsx
# Processing file: number306.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number306.xlsx
# Processing file: number307.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number307.xlsx
# Processing file: number308.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number308.xlsx
# Processing file: number309.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number309.xlsx
# Processing file: number31.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number31.xlsx
# Processing file: number310.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number310.xlsx
# Processing file: number311.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number311.xlsx
# Processing file: number312.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number312.xlsx
# Processing file: number313.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number313.xlsx
# Processing file: number314.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number314.xlsx
# Processing file: number315.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number315.xlsx
# Processing file: number316.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number316.xlsx
# Processing file: number317.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number317.xlsx
# Processing file: number318.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number318.xlsx
# Processing file: number319.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number319.xlsx
# Processing file: number32.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number32.xlsx
# Processing file: number320.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number320.xlsx
# Processing file: number321.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number321.xlsx
# Processing file: number322.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number322.xlsx
# Processing file: number323.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number323.xlsx
# Processing file: number324.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number324.xlsx
# Processing file: number325.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number325.xlsx
# Processing file: number326.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number326.xlsx
# Processing file: number327.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number327.xlsx
# Processing file: number328.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number328.xlsx
# Processing file: number329.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number329.xlsx
# Processing file: number33.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number33.xlsx
# Processing file: number330.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number330.xlsx
# Processing file: number331.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number331.xlsx
# Processing file: number332.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number332.xlsx
# Processing file: number333.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number333.xlsx
# Processing file: number334.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number334.xlsx
# Processing file: number335.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number335.xlsx
# Processing file: number336.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number336.xlsx
# Processing file: number337.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number337.xlsx
# Processing file: number338.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number338.xlsx
# Processing file: number339.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number339.xlsx
# Processing file: number34.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number34.xlsx
# Processing file: number340.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number340.xlsx
# Processing file: number341.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number341.xlsx
# Processing file: number342.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number342.xlsx
# Processing file: number343.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number343.xlsx
# Processing file: number344.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number344.xlsx
# Processing file: number345.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number345.xlsx
# Processing file: number346.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number346.xlsx
# Processing file: number347.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number347.xlsx
# Processing file: number348.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number348.xlsx
# Processing file: number349.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number349.xlsx
# Processing file: number35.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number35.xlsx
# Processing file: number350.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number350.xlsx
# Processing file: number351.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number351.xlsx
# Processing file: number352.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number352.xlsx
# Processing file: number353.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number353.xlsx
# Processing file: number354.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number354.xlsx
# Processing file: number355.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number355.xlsx
# Processing file: number356.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number356.xlsx
# Processing file: number357.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number357.xlsx
# Processing file: number358.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number358.xlsx
# Processing file: number359.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number359.xlsx
# Processing file: number36.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number36.xlsx
# Processing file: number360.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number360.xlsx
# Processing file: number361.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number361.xlsx
# Processing file: number362.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number362.xlsx
# Processing file: number363.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number363.xlsx
# Processing file: number364.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number364.xlsx
# Processing file: number365.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number365.xlsx
# Processing file: number366.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number366.xlsx
# Processing file: number367.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number367.xlsx
# Processing file: number368.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number368.xlsx
# Processing file: number369.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number369.xlsx
# Processing file: number37.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number37.xlsx
# Processing file: number370.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number370.xlsx
# Processing file: number371.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number371.xlsx
# Processing file: number372.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number372.xlsx
# Processing file: number373.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number373.xlsx
# Processing file: number374.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number374.xlsx
# Processing file: number375.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number375.xlsx
# Processing file: number376.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number376.xlsx
# Processing file: number377.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number377.xlsx
# Processing file: number378.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number378.xlsx
# Processing file: number379.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number379.xlsx
# Processing file: number38.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number38.xlsx
# Processing file: number380.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number380.xlsx
# Processing file: number381.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number381.xlsx
# Processing file: number382.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number382.xlsx
# Processing file: number383.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number383.xlsx
# Processing file: number384.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number384.xlsx
# Processing file: number385.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number385.xlsx
# Processing file: number386.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number386.xlsx
# Processing file: number387.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number387.xlsx
# Processing file: number388.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number388.xlsx
# Processing file: number389.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number389.xlsx
# Processing file: number39.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number39.xlsx
# Processing file: number390.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number390.xlsx
# Processing file: number391.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number391.xlsx
# Processing file: number392.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number392.xlsx
# Processing file: number393.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number393.xlsx
# Processing file: number394.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number394.xlsx
# Processing file: number395.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number395.xlsx
# Processing file: number396.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number396.xlsx
# Processing file: number397.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number397.xlsx
# Processing file: number398.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number398.xlsx
# Processing file: number399.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number399.xlsx
# Processing file: number4.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number4.xlsx
# Processing file: number40.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number40.xlsx
# Processing file: number400.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number400.xlsx
# Processing file: number401.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number401.xlsx
# Processing file: number402.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number402.xlsx
# Processing file: number403.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number403.xlsx
# Processing file: number404.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number404.xlsx
# Processing file: number405.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number405.xlsx
# Processing file: number406.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number406.xlsx
# Processing file: number407.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number407.xlsx
# Processing file: number408.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number408.xlsx
# Processing file: number409.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number409.xlsx
# Processing file: number41.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number41.xlsx
# Processing file: number410.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number410.xlsx
# Processing file: number411.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number411.xlsx
# Processing file: number412.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number412.xlsx
# Processing file: number413.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number413.xlsx
# Processing file: number414.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number414.xlsx
# Processing file: number415.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number415.xlsx
# Processing file: number416.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number416.xlsx
# Processing file: number417.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number417.xlsx
# Processing file: number418.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number418.xlsx
# Processing file: number419.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number419.xlsx
# Processing file: number42.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number42.xlsx
# Processing file: number420.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number420.xlsx
# Processing file: number421.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number421.xlsx
# Processing file: number422.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number422.xlsx
# Processing file: number423.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number423.xlsx
# Processing file: number424.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number424.xlsx
# Processing file: number425.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number425.xlsx
# Processing file: number426.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number426.xlsx
# Processing file: number427.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number427.xlsx
# Processing file: number428.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number428.xlsx
# Processing file: number429.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number429.xlsx
# Processing file: number43.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number43.xlsx
# Processing file: number430.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number430.xlsx
# Processing file: number431.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number431.xlsx
# Processing file: number432.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number432.xlsx
# Processing file: number433.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number433.xlsx
# Processing file: number434.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number434.xlsx
# Processing file: number435.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number435.xlsx
# Processing file: number436.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number436.xlsx
# Processing file: number437.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number437.xlsx
# Processing file: number438.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number438.xlsx
# Processing file: number439.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number439.xlsx
# Processing file: number44.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number44.xlsx
# Processing file: number440.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number440.xlsx
# Processing file: number441.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number441.xlsx
# Processing file: number442.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number442.xlsx
# Processing file: number443.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number443.xlsx
# Processing file: number444.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number444.xlsx
# Processing file: number445.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number445.xlsx
# Processing file: number446.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number446.xlsx
# Processing file: number447.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number447.xlsx
# Processing file: number448.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number448.xlsx
# Processing file: number449.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number449.xlsx
# Processing file: number45.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number45.xlsx
# Processing file: number450.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number450.xlsx
# Processing file: number451.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number451.xlsx
# Processing file: number452.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number452.xlsx
# Processing file: number453.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number453.xlsx
# Processing file: number454.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number454.xlsx
# Processing file: number455.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number455.xlsx
# Processing file: number456.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number456.xlsx
# Processing file: number457.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number457.xlsx
# Processing file: number458.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number458.xlsx
# Processing file: number459.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number459.xlsx
# Processing file: number46.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number46.xlsx
# Processing file: number460.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number460.xlsx
# Processing file: number461.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number461.xlsx
# Processing file: number462.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number462.xlsx
# Processing file: number463.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number463.xlsx
# Processing file: number464.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number464.xlsx
# Processing file: number465.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number465.xlsx
# Processing file: number466.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number466.xlsx
# Processing file: number467.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number467.xlsx
# Processing file: number468.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number468.xlsx
# Processing file: number469.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number469.xlsx
# Processing file: number47.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number47.xlsx
# Processing file: number470.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number470.xlsx
# Processing file: number471.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number471.xlsx
# Processing file: number472.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number472.xlsx
# Processing file: number473.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number473.xlsx
# Processing file: number474.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number474.xlsx
# Processing file: number475.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number475.xlsx
# Processing file: number476.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number476.xlsx
# Processing file: number477.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number477.xlsx
# Processing file: number478.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number478.xlsx
# Processing file: number479.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number479.xlsx
# Processing file: number48.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number48.xlsx
# Processing file: number480.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number480.xlsx
# Processing file: number481.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number481.xlsx
# Processing file: number482.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number482.xlsx
# Processing file: number483.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number483.xlsx
# Processing file: number484.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number484.xlsx
# Processing file: number485.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number485.xlsx
# Processing file: number486.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number486.xlsx
# Processing file: number487.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number487.xlsx
# Processing file: number488.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number488.xlsx
# Processing file: number489.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number489.xlsx
# Processing file: number49.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number49.xlsx
# Processing file: number490.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number490.xlsx
# Processing file: number491.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number491.xlsx
# Processing file: number492.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number492.xlsx
# Processing file: number493.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number493.xlsx
# Processing file: number494.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number494.xlsx
# Processing file: number495.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number495.xlsx
# Processing file: number496.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number496.xlsx
# Processing file: number497.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number497.xlsx
# Processing file: number498.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number498.xlsx
# Processing file: number499.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number499.xlsx
# Processing file: number5.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number5.xlsx
# Processing file: number50.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number50.xlsx
# Processing file: number500.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number500.xlsx
# Processing file: number501.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number501.xlsx
# Processing file: number502.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number502.xlsx
# Processing file: number503.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number503.xlsx
# Processing file: number504.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number504.xlsx
# Processing file: number505.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number505.xlsx
# Processing file: number506.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number506.xlsx
# Processing file: number507.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number507.xlsx
# Processing file: number508.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number508.xlsx
# Processing file: number509.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number509.xlsx
# Processing file: number51.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number51.xlsx
# Processing file: number510.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number510.xlsx
# Processing file: number511.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number511.xlsx
# Processing file: number512.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number512.xlsx
# Processing file: number513.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number513.xlsx
# Processing file: number514.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number514.xlsx
# Processing file: number515.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number515.xlsx
# Processing file: number516.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number516.xlsx
# Processing file: number517.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number517.xlsx
# Processing file: number518.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number518.xlsx
# Processing file: number519.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number519.xlsx
# Processing file: number52.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number52.xlsx
# Processing file: number520.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number520.xlsx
# Processing file: number521.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number521.xlsx
# Processing file: number522.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number522.xlsx
# Processing file: number523.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number523.xlsx
# Processing file: number524.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number524.xlsx
# Processing file: number525.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number525.xlsx
# Processing file: number526.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number526.xlsx
# Processing file: number527.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number527.xlsx
# Processing file: number528.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number528.xlsx
# Processing file: number529.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number529.xlsx
# Processing file: number53.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number53.xlsx
# Processing file: number530.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number530.xlsx
# Processing file: number531.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number531.xlsx
# Processing file: number532.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number532.xlsx
# Processing file: number533.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number533.xlsx
# Processing file: number534.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number534.xlsx
# Processing file: number535.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number535.xlsx
# Processing file: number536.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number536.xlsx
# Processing file: number537.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number537.xlsx
# Processing file: number538.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number538.xlsx
# Processing file: number539.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number539.xlsx
# Processing file: number54.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number54.xlsx
# Processing file: number540.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number540.xlsx
# Processing file: number541.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number541.xlsx
# Processing file: number542.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number542.xlsx
# Processing file: number543.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number543.xlsx
# Processing file: number544.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number544.xlsx
# Processing file: number545.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number545.xlsx
# Processing file: number546.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number546.xlsx
# Processing file: number547.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number547.xlsx
# Processing file: number548.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number548.xlsx
# Processing file: number549.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number549.xlsx
# Processing file: number55.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number55.xlsx
# Processing file: number550.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number550.xlsx
# Processing file: number551.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number551.xlsx
# Processing file: number552.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number552.xlsx
# Processing file: number553.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number553.xlsx
# Processing file: number554.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number554.xlsx
# Processing file: number555.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number555.xlsx
# Processing file: number556.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number556.xlsx
# Processing file: number557.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number557.xlsx
# Processing file: number558.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number558.xlsx
# Processing file: number559.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number559.xlsx
# Processing file: number56.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number56.xlsx
# Processing file: number560.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number560.xlsx
# Processing file: number561.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number561.xlsx
# Processing file: number562.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number562.xlsx
# Processing file: number563.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number563.xlsx
# Processing file: number564.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number564.xlsx
# Processing file: number565.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number565.xlsx
# Processing file: number566.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number566.xlsx
# Processing file: number567.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number567.xlsx
# Processing file: number568.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number568.xlsx
# Processing file: number569.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number569.xlsx
# Processing file: number57.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number57.xlsx
# Processing file: number570.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number570.xlsx
# Processing file: number571.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number571.xlsx
# Processing file: number572.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number572.xlsx
# Processing file: number573.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number573.xlsx
# Processing file: number574.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number574.xlsx
# Processing file: number575.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number575.xlsx
# Processing file: number576.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number576.xlsx
# Processing file: number577.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number577.xlsx
# Processing file: number578.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number578.xlsx
# Processing file: number579.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number579.xlsx
# Processing file: number58.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number58.xlsx
# Processing file: number580.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number580.xlsx
# Processing file: number581.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number581.xlsx
# Processing file: number582.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number582.xlsx
# Processing file: number583.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number583.xlsx
# Processing file: number584.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number584.xlsx
# Processing file: number585.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number585.xlsx
# Processing file: number586.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number586.xlsx
# Processing file: number587.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number587.xlsx
# Processing file: number588.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number588.xlsx
# Processing file: number589.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number589.xlsx
# Processing file: number59.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number59.xlsx
# Processing file: number590.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number590.xlsx
# Processing file: number591.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number591.xlsx
# Processing file: number592.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number592.xlsx
# Processing file: number593.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number593.xlsx
# Processing file: number594.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number594.xlsx
# Processing file: number595.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number595.xlsx
# Processing file: number596.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number596.xlsx
# Processing file: number597.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number597.xlsx
# Processing file: number598.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number598.xlsx
# Processing file: number599.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number599.xlsx
# Processing file: number6.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number6.xlsx
# Processing file: number60.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number60.xlsx
# Processing file: number600.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number600.xlsx
# Processing file: number61.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number61.xlsx
# Processing file: number62.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number62.xlsx
# Processing file: number63.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number63.xlsx
# Processing file: number64.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number64.xlsx
# Processing file: number65.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number65.xlsx
# Processing file: number66.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number66.xlsx
# Processing file: number67.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number67.xlsx
# Processing file: number68.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number68.xlsx
# Processing file: number69.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number69.xlsx
# Processing file: number7.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number7.xlsx
# Processing file: number70.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number70.xlsx
# Processing file: number71.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number71.xlsx
# Processing file: number72.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number72.xlsx
# Processing file: number73.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number73.xlsx
# Processing file: number74.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number74.xlsx
# Processing file: number75.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number75.xlsx
# Processing file: number76.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number76.xlsx
# Processing file: number77.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number77.xlsx
# Processing file: number78.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number78.xlsx
# Processing file: number79.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number79.xlsx
# Processing file: number8.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number8.xlsx
# Processing file: number80.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number80.xlsx
# Processing file: number81.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number81.xlsx
# Processing file: number82.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number82.xlsx
# Processing file: number83.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number83.xlsx
# Processing file: number84.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number84.xlsx
# Processing file: number85.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number85.xlsx
# Processing file: number86.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number86.xlsx
# Processing file: number87.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number87.xlsx
# Processing file: number88.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number88.xlsx
# Processing file: number89.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number89.xlsx
# Processing file: number9.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number9.xlsx
# Processing file: number90.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number90.xlsx
# Processing file: number91.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number91.xlsx
# Processing file: number92.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number92.xlsx
# Processing file: number93.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number93.xlsx
# Processing file: number94.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number94.xlsx
# Processing file: number95.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number95.xlsx
# Processing file: number96.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number96.xlsx
# Processing file: number97.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number97.xlsx
# Processing file: number98.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number98.xlsx
# Processing file: number99.tsv
# Excel file created: C:\Users\HP\Downloads\proj\individual\number99.xlsx
# Processing complete.
# Skipping CLEANED_MERGED_RESULT_.xlsx due to missing columns.
# Skipping new.xlsx due to missing columns.
# Skipping NEW_MERGED_RESULT_.xlsx due to missing columns.
# Processing complete. File saved to C:\Users\HP\Downloads\proj\individual\result.xlsx.

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\HP\Downloads\proj\individual\result.xlsx')
df
# Out:
#                  employerName employerAddressStreet_name employerAddressCity  \
# 0     Collins-SaundersandSons     9652ScottGrovesApt.116      Rodriguezmouth
# 1             CabreraGroupLtd   5553ThomasPassageApt.705        WestTheodore
# 2        George-HortonandSons         55527ShannonCorner          Alisonfort
# 3            Munoz-JohnsonLtd             286SmithCircle      NorthJuliaview
# 4     Clark,BrownandRiveraLLC        9446SamanthaSprings        Williamsstad
# ..                        ...                        ...                 ...
# 595            WalkerGroupPLC         88429AnnetteFields     SouthJoshuafort
# 596           Decker-SmithPLC       784PriceBrookApt.000           Marksstad
# 597                       NaN           35657JamesCourts         WestJasmine
# 598  Tyler,NelsonandBenderInc             5654ParkerView           NorthSara
# 599  Cook,BaileyandOsborneLLC    18222LoriCornerSuite847         Johnnyhaven
#
#     employerAddressState employerAddressZip einEmployerIdentificationNumber  \
# 0                     NE         70838-1080                      37-3493491
# 1                     Co         56221-5487                      50-4141334
# 2                     LA         24369-8354                      43-1414035
# 3                     VA         85011-4757                      71-8393024
# 4                     NC         25420-6106                      90-9375060
# ..                   ...                ...                             ...
# 595                   PA         34492-5445                      42-1551597
# 596                   ME         92936-1367                      30-9755097
# 597                   NM         04093-1257                      68-7884298
# 598                   AZ         50949-7371                      98-3866411
# 599                   KS         35382-4589                      10-8875958
#
#          employeeName ssnOfEmployee  box1WagesTipsAndOtherCompensations  \
# 0     StephanieDawson   720-74-9502                            41669.07
# 1     MelissaAnderson           NaN                           214731.04
# 2         RodneyPerez   475-90-1539                           240614.35
# 3          GaryFisher   638-62-9924                           241992.09
# 4       NicholeSutton   475-13-3309                           175675.50
# ..                ...           ...                                 ...
# 595       MeredithLee           NaN                            86860.24
# 596      Mrs.Samantha   numDog-2077                         19087958.00
# 597          SaraDean   708-85-6052                            62278.33
# 598    TiffanySimmons             0                           110503.15
# 599  DanielHarrington   325-64-9593                           108293.29
#
#      box2FederalIncomeTaxWithheld  box3SocialSecurityWages  \
# 0                    11182.930000                 53826.13
# 1                    47393.740000                211281.72
# 2                    79673.630000                266460.93
# 3                    30996.510000                270761.69
# 4                    38786.940000                124567.41
# ..                            ...                      ...
# 595                  10064.600000                 64063.69
# 596                      0.537333                      NaN
# 597                           NaN                      NaN
# 598                  15540.510000                 82512.35
# 599                  32329.360000                116037.05
#
#      box4SocialSecurityTaxWithheld  box16StateWagesTips  box17StateIncomeTax  \
# 0                          4117.70         2.028785e+04              1690.44
# 1                         16163.05         1.210590e+09                  NaN
# 2                         20384.26         1.208543e+05              8990.12
# 3                         20713.27         1.224533e+08             13763.03
# 4                          9529.41         9.300751e+04              4515.21
# ..                             ...                  ...                  ...
# 595                        4900.87         4.756493e+04              2880.29
# 596                            NaN         8.378236e+06                  NaN
# 597                            NaN                  NaN           -283239.00
# 598                        6312.19         5.617204e+04              5554.06
# 599                        8876.83         5.560953e+04              6244.84
#
#      taxYear
# 0     2019.0
# 1     2018.0
# 2     2019.0
# 3     2019.0
# 4     2019.0
# ..       ...
# 595   2018.0
# 596   2018.0
# 597   2018.0
# 598      NaN
# 599   2019.0
#
# [600 rows x 15 columns]

# %%
print(df.dtypes)
# Out:
# employerName                           object
# employerAddressStreet_name             object
# employerAddressCity                    object
# employerAddressState                   object
# employerAddressZip                     object
# einEmployerIdentificationNumber        object
# employeeName                           object
# ssnOfEmployee                          object
# box1WagesTipsAndOtherCompensations    float64
# box2FederalIncomeTaxWithheld          float64
# box3SocialSecurityWages               float64
# box4SocialSecurityTaxWithheld         float64
# box16StateWagesTips                   float64
# box17StateIncomeTax                   float64
# taxYear                               float64
# dtype: object
